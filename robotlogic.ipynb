# %%
import serial
ser = serial.Serial('COM3', 115200)  # open serial port
time.sleep(2)   # allow Arduino to reset

while True:
    line = ser.readline().decode().strip()   # read a '\n' terminated line
    print(line)
